# %% [markdown]
# # Data Visualization
# It is graphical representation of information and data.
# Visual elements like charts, graphs and maps, data visualizations tools.
# - Ploting Libraries:
#
#     ➤ Matplotlib: low level, provides lots of freedom
#
#     ➤ Pandas Visualization: easy to use interface, built on Matplotlib
#
#     ➤ Seaborn: high-level interface, great default styles
#
#     ➤ ggplot: based on R's ggplot2, uses Grammar of Graphics
#
#     ➤ Plotly: can create interactive plots
#
# - Matplotlib
#
#
# ➤ Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy.
#
# ➤ Matplotlib is a python library used for Data Visualization.
#
# ➤ Matplotlib is 2D and 3D plotting python library.
#
# ➤ It was introduced by john hunter in the year 2002.
#
# - Types of plot:
#
#     ➤ Linear Plot
#
#     ➤ Scatter Plot
#
#     ➤ Bar Plot
#
#     ➤ Stem Plot
#
#     ➤ Step Plot
#
#     ➤ Hist Plot
#
#     ➤ Box Plot
#
#     ➤ Pie Plot
#
#     ➤ Fill_Between Plo

# %% [markdown]
#     Line Plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=['Python','Java','C','C++']
y=[78,90,64,22]
plt.xlabel('x-axis',fontsize=14)
plt.ylabel('y-axis',fontsize=14)
plt.ylabel('y-axis')
plt.title('Programming Language')
c=['b','c','g','y']
plt.bar(x,y,width=0.3,color=c,edgecolor='black',linewidth=2,linestyle='-',alpha=0.5,label='Percentage')
plt.legend()
plt.show()

# %%
x=['Python','Java','C','C++']
y=[78,60,64,20]
z=[20,30,40,50]

width=0.2
p=np.arange(len(x))
p1=[j+width for j in p]

plt.xlabel('x-axis',fontsize=14)
plt.ylabel('y-axis',fontsize=14)

plt.title('Programming Language')



plt.bar(p,y,width,color='g',label='Percentage1')
plt.bar(p1,z,width,color='c',label='Percentage2')

plt.xticks(p+width/2,x,rotation=10)
plt.legend()
plt.show()

# %% [markdown]
#     Scatter Plot

# %%
x=[1,2,3,4,5,6,7]
y=[8,4,3,22,25,7,11]


#c=['b','c','g','y','hotpink','brown','purple',]
colors=[100,35,789,85,54,32,66]
sizes=[59,34,56,68,32,21,90]
#plt.scatter(x,y,color=c,s=sizes,marker='*',edgecolor='black',linewidth=0.2,cmap='virdis')

plt.scatter(x,y,c=colors,s=sizes,marker='*',cmap='rainbow')
plt.colorbar()
plt.title('Scatter Plot',fontsize=8)
plt.xlabel('x-axis',fontsize=14)
plt.ylabel('y-axis',fontsize=14)

plt.show()
